# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv("SALES.csv")
sales
# Out:
#      Unnamed: 0 first_name last_name country  phone_number  \
# 0             0      Anita      Ruiz  Canada  2.507667e+11
# 1             1      Anita      Ruiz  Canada  2.507667e+11
# 2             2      Anita      Ruiz  Canada  2.507667e+11
# 3             3      Anita      Ruiz  Canada  2.507667e+11
# 4             4      Anita      Ruiz  Canada  2.507667e+11
# ..          ...        ...       ...     ...           ...
# 513         513     Latoya  Andersen  Canada  2.507667e+11
# 514         514     Latoya  Andersen  Canada  2.507667e+11
# 515         515     Latoya  Andersen  Canada  2.507667e+11
# 516         516     Latoya  Andersen  Canada  2.507667e+11
# 517         517     Latoya  Andersen  Canada  2.507667e+11
#
#      sales_contact_code  invoice_number invoice_date   total
# 0                     3              47   2021-04-02    99.0
# 1                     3              68   2020-12-17   396.0
# 2                     3             157   2023-06-03  1485.0
# ...

# %%
sales['first_name']
# Out:
# 0       Anita
# 1       Anita
# 2       Anita
# 3       Anita
# 4       Anita
#         ...
# 513    Latoya
# 514    Latoya
# 515    Latoya
# 516    Latoya
# 517    Latoya
# Name: first_name, Length: 518, dtype: object

# %%
sales[['first_name', 'last_name','total']]
# Out:
#     first_name last_name   total
# 0        Anita      Ruiz    99.0
# 1        Anita      Ruiz   396.0
# 2        Anita      Ruiz  1485.0
# 3        Anita      Ruiz   198.0
# 4        Anita      Ruiz   594.0
# ..         ...       ...     ...
# 513     Latoya  Andersen    99.0
# 514     Latoya  Andersen   594.0
# 515     Latoya  Andersen   396.0
# 516     Latoya  Andersen  1683.0
# 517     Latoya  Andersen   693.0
#
# [518 rows x 3 columns]

# %% [markdown]
# Displayinh unique value

# %%
sales['first_name'].unique()
# Out:
# array(['Anita', 'Kimberly', 'Daniel', 'Mark', 'Debbie', 'Wendy', 'Brandi',
#        'Paul', 'Richard', 'Kristin', 'Ronald', 'Brian', 'Trevor', 'Laura',
#        'Elizabeth', 'Tiffany', 'Stephanie', 'Linda', 'Steven', 'Chloe',
#        'Rachel', 'Dorothy', 'Nathan', 'Brandon', 'Gerald', 'Lee',
#        'Patrick', 'Aaron', 'Brittany', 'Jennifer', 'Laurie', 'Amy',
#        'Casey', 'Amber', 'Anthony', 'James', 'Leah', 'Andrew', 'Jonathan',
#        'Cheyenne', 'Kelly', 'Sara', 'Victor', 'Latoya'], dtype=object)

# %%
our_columns = sales.columns
our_columns
# Out:
# Index(['Unnamed: 0', 'first_name', 'last_name', 'country', 'phone_number',
#        'sales_contact_code', 'invoice_number', 'invoice_date', 'total'],
#       dtype='object')

# %%
for column in our_columns:
    print(column)
# Out:
# Unnamed: 0
# first_name
# last_name
# country
# phone_number
# sales_contact_code
# invoice_number
# invoice_date
# total

# %% [markdown]
# Value_count function

# %%
sales['first_name'].value_counts(normalize=True)
# Out:
# Laura        0.046332
# Mark         0.042471
# Richard      0.040541
# Steven       0.038610
# Victor       0.034749
# Amy          0.032819
# Kelly        0.028958
# Kimberly     0.027027
# Anita        0.025097
# Debbie       0.025097
# Leah         0.025097
# Jennifer     0.025097
# Tiffany      0.023166
# Lee          0.023166
# Nathan       0.023166
# Latoya       0.023166
# Brian        0.023166
# Daniel       0.023166
# Sara         0.021236
# Wendy        0.021236
# Cheyenne     0.021236
# Laurie       0.021236
# Elizabeth    0.021236
# Linda        0.021236
# Kristin      0.019305
# Patrick      0.019305
# Chloe        0.019305
# Jonathan     0.019305
# Dorothy      0.019305
# Andrew       0.019305
# Brandi       0.019305
# James        0.017375
# Rachel       0.017375
# Brandon      0.017375
# Paul         0.017375
# Brittany     0.017375
# Aaron        0.017375
# Ronald       0.017375
# Amber        0.017375
# Casey        0.015444
# Stephanie    0.015444
# ...

# %%
sales['first_name'].value_counts(normalize=True)
# Out:
# Laura        4.633205
# Mark         4.247104
# Richard      4.054054
# Steven       3.861004
# Victor       3.474903
# Amy          3.281853
# Kelly        2.895753
# Kimberly     2.702703
# Anita        2.509653
# Debbie       2.509653
# Leah         2.509653
# Jennifer     2.509653
# Tiffany      2.316602
# Lee          2.316602
# Nathan       2.316602
# Latoya       2.316602
# Brian        2.316602
# Daniel       2.316602
# Sara         2.123552
# Wendy        2.123552
# Cheyenne     2.123552
# Laurie       2.123552
# Elizabeth    2.123552
# Linda        2.123552
# Kristin      1.930502
# Patrick      1.930502
# Chloe        1.930502
# Jonathan     1.930502
# Dorothy      1.930502
# Andrew       1.930502
# Brandi       1.930502
# James        1.737452
# Rachel       1.737452
# Brandon      1.737452
# Paul         1.737452
# Brittany     1.737452
# Aaron        1.737452
# Ronald       1.737452
# Amber        1.737452
# Casey        1.544402
# Stephanie    1.544402
# ...

# %%
sales['first_name'].value_counts(dropna=False, normalize=True)
# Out:
# Laura        0.046332
# Mark         0.042471
# Richard      0.040541
# Steven       0.038610
# Victor       0.034749
# Amy          0.032819
# Kelly        0.028958
# Kimberly     0.027027
# Anita        0.025097
# Debbie       0.025097
# Leah         0.025097
# Jennifer     0.025097
# Tiffany      0.023166
# Lee          0.023166
# Nathan       0.023166
# Latoya       0.023166
# Brian        0.023166
# Daniel       0.023166
# Sara         0.021236
# Wendy        0.021236
# Cheyenne     0.021236
# Laurie       0.021236
# Elizabeth    0.021236
# Linda        0.021236
# Kristin      0.019305
# Patrick      0.019305
# Chloe        0.019305
# Jonathan     0.019305
# Dorothy      0.019305
# Andrew       0.019305
# Brandi       0.019305
# James        0.017375
# Rachel       0.017375
# Brandon      0.017375
# Paul         0.017375
# Brittany     0.017375
# Aaron        0.017375
# Ronald       0.017375
# Amber        0.017375
# Casey        0.015444
# Stephanie    0.015444
# ...

# %%
sales['phone_number'].value_counts(dropna=False, normalize=True)*100
# Out:
# NaN             3.474903
# 2.507667e+11    2.895753
# 2.507667e+11    2.509653
# 2.507667e+11    2.509653
# 2.507667e+11    2.509653
# 2.507667e+11    2.509653
# 2.507667e+11    2.509653
# 2.507667e+11    2.509653
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.316602
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    2.123552
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.930502
# 2.507667e+11    1.737452
# 2.507667e+11    1.737452
# 2.507667e+11    1.737452
# 2.507667e+11    1.737452
# 2.507667e+11    1.737452
# ...

# %% [markdown]
# List and Dictionary are important in data engineering

# %%
sales.shape[0]
# Out:
# 518

# %%
sales.shape[1]
# Out:
# 9

# %%
names = ['John', 'Ben','Lily','Alice', 'Bob']

# %%
names[2]
# Out:
# 'Lily'

# %%
names[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/1p/g776wbgs3n7c9fhr9z76d7t80000gn/T/ipykernel_6073/3079811678.py in <module>
# ----> 1 names[10]
#
# IndexError: list index out of range

# %%
names[4]
# Out:
# 'Bob'

# %%
len(names)
# Out:
# 5

# %% [markdown]
# Using negative index

# %%
names[-1]
# Out:
# 'Bob'

# %%
names[0:3]
# Out:
# ['John', 'Ben', 'Lily']

# %%
names[:3]
# Out:
# ['John', 'Ben', 'Lily']

# %%
names[:-3]
# Out:
# ['John', 'Ben']

# %% [markdown]
# DATAFRMAE SLICING WITH iloc and loc

# %%
sales.iloc[0:10,1:3]
# Out:
#   first_name last_name
# 0      Anita      Ruiz
# 1      Anita      Ruiz
# 2      Anita      Ruiz
# 3      Anita      Ruiz
# 4      Anita      Ruiz
# 5      Anita      Ruiz
# 6      Anita      Ruiz
# 7      Anita      Ruiz
# 8      Anita      Ruiz
# 9      Anita      Ruiz

# %%
sales.iloc[:10,1:3]
# Out:
#   first_name last_name
# 0      Anita      Ruiz
# 1      Anita      Ruiz
# 2      Anita      Ruiz
# 3      Anita      Ruiz
# 4      Anita      Ruiz
# 5      Anita      Ruiz
# 6      Anita      Ruiz
# 7      Anita      Ruiz
# 8      Anita      Ruiz
# 9      Anita      Ruiz

# %%
sales.iloc[0:10,1:-2]
# Out:
#   first_name last_name country  phone_number  sales_contact_code  \
# 0      Anita      Ruiz  Canada  2.507667e+11                   3
# 1      Anita      Ruiz  Canada  2.507667e+11                   3
# 2      Anita      Ruiz  Canada  2.507667e+11                   3
# 3      Anita      Ruiz  Canada  2.507667e+11                   3
# 4      Anita      Ruiz  Canada  2.507667e+11                   3
# 5      Anita      Ruiz  Canada  2.507667e+11                   3
# 6      Anita      Ruiz  Canada  2.507667e+11                   3
# 7      Anita      Ruiz  Canada  2.507667e+11                   3
# 8      Anita      Ruiz  Canada  2.507667e+11                   3
# 9      Anita      Ruiz  Canada  2.507667e+11                   3
#
#    invoice_number
# 0              47
# 1              68
# 2             157
# 3             158
# 4             214
# 5             228
# 6             232
# 7             254
# 8             324
# 9             335

# %%
sales.iloc[100:150,3:7]
# Out:
#     country  phone_number  sales_contact_code  invoice_number
# 100  Brazil  2.507667e+11                   5             599
# 101  Brazil  2.507667e+11                   5             607
# 102     USA  2.507667e+11                   5              40
# 103     USA  2.507667e+11                   5             196
# 104     USA  2.507667e+11                   5             273
# 105     USA  2.507667e+11                   5             308
# 106     USA  2.507667e+11                   5             349
# 107     USA  2.507667e+11                   5             426
# 108     USA  2.507667e+11                   5             457
# 109     USA  2.507667e+11                   5             485
# 110     USA  2.507667e+11                   5             540
# 111     USA  2.507667e+11                   5             566
# 112  France  2.507667e+11                   4              11
# 113  France  2.507667e+11                   4              59
# ...

# %%
sales.iloc[100:150,3:7].shape
# Out:
# (50, 4)

# %%
sales.iloc[100:150,].shape
# Out:
# (50, 9)

# %%
sales.iloc[:,3:]
# Out:
#     country  phone_number  sales_contact_code  invoice_number invoice_date  \
# 0    Canada  2.507667e+11                   3              47   2021-04-02
# 1    Canada  2.507667e+11                   3              68   2020-12-17
# 2    Canada  2.507667e+11                   3             157   2023-06-03
# 3    Canada  2.507667e+11                   3             158   2022-05-03
# 4    Canada  2.507667e+11                   3             214   2023-04-17
# ..      ...           ...                 ...             ...          ...
# 513  Canada  2.507667e+11                   4             352   2022-06-02
# 514  Canada  2.507667e+11                   4             406   2020-07-26
# 515  Canada  2.507667e+11                   4             482   2022-03-24
# 516  Canada  2.507667e+11                   4             495   2023-07-21
# 517  Canada  2.507667e+11                   4             534   2023-01-31
#
#       total
# 0      99.0
# 1     396.0
# 2    1485.0
# 3     198.0
# ...

# %%
# this one count on the provided records

sales.loc[10:20, 'first_name':'country']
# Out:
#    first_name  last_name         country
# 10      Anita       Ruiz          Canada
# 11      Anita       Ruiz          Canada
# 12      Anita       Ruiz          Canada
# 13   Kimberly     Taylor  United Kingdom
# 14   Kimberly     Taylor  United Kingdom
# 15   Kimberly     Taylor  United Kingdom
# 16   Kimberly     Taylor  United Kingdom
# 17   Kimberly     Taylor  United Kingdom
# 18     Daniel  Wilkerson             USA
# 19     Daniel  Wilkerson             USA
# 20     Daniel  Wilkerson             USA

# %%
sales_samples = sales.sample(30)

# %%
sales_samples
# Out:
#      Unnamed: 0 first_name  last_name         country  phone_number  \
# 183         183  Stephanie    Watkins     Netherlands  2.507667e+11
# 73           73      Wendy      Brown          Canada  2.507667e+11
# 339         339   Jennifer      Yates  Czech Republic  2.507667e+11
# 36           36       Mark   Martinez         Finland  2.507667e+11
# 350         350     Laurie     Hanson          France  2.507667e+11
# 123         123      Brian   Williams          Brazil  2.507667e+11
# 136         136     Trevor      Smith          Canada  2.507667e+11
# 196         196     Steven    Everett         Germany  2.507667e+11
# 168         168    Tiffany    Stanton  Czech Republic  2.507667e+11
# 324         324   Brittany   Richards         Germany  2.507667e+11
# 175         175    Tiffany    Stanton  Czech Republic  2.507667e+11
# 479         479       Sara        Lee             USA  2.507667e+11
# 219         219     Rachel      Burke         Denmark  2.507667e+11
# ...

# %%
sales_samples.iloc[:10,:]
# Out:
#      Unnamed: 0 first_name last_name         country  phone_number  \
# 183         183  Stephanie   Watkins     Netherlands  2.507667e+11
# 73           73      Wendy     Brown          Canada  2.507667e+11
# 339         339   Jennifer     Yates  Czech Republic  2.507667e+11
# 36           36       Mark  Martinez         Finland  2.507667e+11
# 350         350     Laurie    Hanson          France  2.507667e+11
# 123         123      Brian  Williams          Brazil  2.507667e+11
# 136         136     Trevor     Smith          Canada  2.507667e+11
# 196         196     Steven   Everett         Germany  2.507667e+11
# 168         168    Tiffany   Stanton  Czech Republic  2.507667e+11
# 324         324   Brittany  Richards         Germany  2.507667e+11
#
#      sales_contact_code  invoice_number invoice_date   total
# 183                   3             559   2021-06-24   792.0
# 73                    3             538   2022-11-24   297.0
# ...

# %%
sales_samples.loc[:,10:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1p/g776wbgs3n7c9fhr9z76d7t80000gn/T/ipykernel_6073/3331270198.py in <module>
# ----> 1 sales_samples.loc[:,10:]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %% [markdown]
# FILTERING

# %%
sales[sales['first_name'] == 'Anita']
# Out:
#     Unnamed: 0 first_name last_name country  phone_number  sales_contact_code  \
# 0            0      Anita      Ruiz  Canada  2.507667e+11                   3
# 1            1      Anita      Ruiz  Canada  2.507667e+11                   3
# 2            2      Anita      Ruiz  Canada  2.507667e+11                   3
# 3            3      Anita      Ruiz  Canada  2.507667e+11                   3
# 4            4      Anita      Ruiz  Canada  2.507667e+11                   3
# 5            5      Anita      Ruiz  Canada  2.507667e+11                   3
# 6            6      Anita      Ruiz  Canada  2.507667e+11                   3
# 7            7      Anita      Ruiz  Canada  2.507667e+11                   3
# 8            8      Anita      Ruiz  Canada  2.507667e+11                   3
# 9            9      Anita      Ruiz  Canada  2.507667e+11                   3
# 10          10      Anita      Ruiz  Canada  2.507667e+11                   3
# ...

# %%
sales['first_name'] == 'Anita'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 513    False
# 514    False
# 515    False
# 516    False
# 517    False
# Name: first_name, Length: 518, dtype: bool

# %%
sales[(sales['sales_contact_code']==3) & (sales['country']=='Canada')]
# Out:
#      Unnamed: 0 first_name last_name country  phone_number  \
# 0             0      Anita      Ruiz  Canada  2.507667e+11
# 1             1      Anita      Ruiz  Canada  2.507667e+11
# 2             2      Anita      Ruiz  Canada  2.507667e+11
# 3             3      Anita      Ruiz  Canada  2.507667e+11
# 4             4      Anita      Ruiz  Canada  2.507667e+11
# 5             5      Anita      Ruiz  Canada  2.507667e+11
# 6             6      Anita      Ruiz  Canada  2.507667e+11
# 7             7      Anita      Ruiz  Canada  2.507667e+11
# 8             8      Anita      Ruiz  Canada  2.507667e+11
# 9             9      Anita      Ruiz  Canada  2.507667e+11
# 10           10      Anita      Ruiz  Canada  2.507667e+11
# 11           11      Anita      Ruiz  Canada  2.507667e+11
# 12           12      Anita      Ruiz  Canada  2.507667e+11
# 64           64      Wendy     Brown  Canada  2.507667e+11
# 65           65      Wendy     Brown  Canada  2.507667e+11
# ...

# %%
sales[(sales['sales_contact_code']==3) & (sales['country']=='Canada')].shape
# Out:
# (34, 9)

# %%
sales[(sales['sales_contact_code']==3)]
# Out:
#      Unnamed: 0 first_name last_name country  phone_number  \
# 0             0      Anita      Ruiz  Canada  2.507667e+11
# 1             1      Anita      Ruiz  Canada  2.507667e+11
# 2             2      Anita      Ruiz  Canada  2.507667e+11
# 3             3      Anita      Ruiz  Canada  2.507667e+11
# 4             4      Anita      Ruiz  Canada  2.507667e+11
# ..          ...        ...       ...     ...           ...
# 501         501     Victor   Mendoza  France           NaN
# 502         502     Victor   Mendoza  France           NaN
# 503         503     Victor   Mendoza  France           NaN
# 504         504     Victor   Mendoza  France           NaN
# 505         505     Victor   Mendoza  France           NaN
#
#      sales_contact_code  invoice_number invoice_date   total
# 0                     3              47   2021-04-02    99.0
# 1                     3              68   2020-12-17   396.0
# 2                     3             157   2023-06-03  1485.0
# ...

# %%
sales[(sales['country']=='Canada')]
# Out:
#      Unnamed: 0 first_name last_name country  phone_number  \
# 0             0      Anita      Ruiz  Canada  2.507667e+11
# 1             1      Anita      Ruiz  Canada  2.507667e+11
# 2             2      Anita      Ruiz  Canada  2.507667e+11
# 3             3      Anita      Ruiz  Canada  2.507667e+11
# 4             4      Anita      Ruiz  Canada  2.507667e+11
# ..          ...        ...       ...     ...           ...
# 513         513     Latoya  Andersen  Canada  2.507667e+11
# 514         514     Latoya  Andersen  Canada  2.507667e+11
# 515         515     Latoya  Andersen  Canada  2.507667e+11
# 516         516     Latoya  Andersen  Canada  2.507667e+11
# 517         517     Latoya  Andersen  Canada  2.507667e+11
#
#      sales_contact_code  invoice_number invoice_date   total
# 0                     3              47   2021-04-02    99.0
# 1                     3              68   2020-12-17   396.0
# 2                     3             157   2023-06-03  1485.0
# ...

# %% [markdown]
# Selecting unique customer within a dataset

# %%
sales['first_name'].unique()
# Out:
# array(['Anita', 'Kimberly', 'Daniel', 'Mark', 'Debbie', 'Wendy', 'Brandi',
#        'Paul', 'Richard', 'Kristin', 'Ronald', 'Brian', 'Trevor', 'Laura',
#        'Elizabeth', 'Tiffany', 'Stephanie', 'Linda', 'Steven', 'Chloe',
#        'Rachel', 'Dorothy', 'Nathan', 'Brandon', 'Gerald', 'Lee',
#        'Patrick', 'Aaron', 'Brittany', 'Jennifer', 'Laurie', 'Amy',
#        'Casey', 'Amber', 'Anthony', 'James', 'Leah', 'Andrew', 'Jonathan',
#        'Cheyenne', 'Kelly', 'Sara', 'Victor', 'Latoya'], dtype=object)

# %%
sales[(sales['country'] == 'USA') & (sales['total'] >= 1000)]['first_name'].unique()
# Out:
# array(['Daniel', 'Brandi', 'Paul', 'Kristin', 'Linda', 'Dorothy', 'Casey',
#        'Kelly', 'Sara'], dtype=object)

# %%
len(sales[(sales['country'] == 'USA') & (sales['total'] >= 1000)]['first_name'].unique())
# Out:
# 9

# %%
sales[(sales['country'] == 'USA') & (sales['total'] >= 1000)]['first_name']
# Out:
# 21      Daniel
# 22      Daniel
# 23      Daniel
# 28      Daniel
# 76      Brandi
# 79      Brandi
# 80      Brandi
# 93        Paul
# 103    Kristin
# 185      Linda
# 188      Linda
# 194      Linda
# 237    Dorothy
# 239    Dorothy
# 379      Casey
# 381      Casey
# 465      Kelly
# 466      Kelly
# 470      Kelly
# 471      Kelly
# 472      Kelly
# 474      Kelly
# 482       Sara
# 483       Sara
# Name: first_name, dtype: object
